# %% [markdown]
# # Lendo a base de conhecimentos do IFood

# %%
import pandas as pd

# %%
df = pd.read_csv("base_conhecimento_ifood_genai-exemplo.csv")
df.head()
# Out:
#       categoria                                           pergunta  \
# 0     reembolso    Quando o cliente tem direito a reembolso total?
# 1     reembolso  O cliente pode pedir reembolso após o pedido s...
# 2     reembolso             Erro do restaurante garante reembolso?
# 3  cancelamento  O que fazer se o restaurante não tiver o item ...
# 4  cancelamento             Cancelamento por falta de ingrediente.
#
#                                             resposta         fonte
# 0  Quando o restaurante cancela o pedido ou quand...  Política 3.2
# 1  Apenas quando houver falha do restaurante, app...  Política 3.2
# 2  Sim, cancelamentos por falha do restaurante ge...  Política 2.1
# 3  Pedido deve ser cancelado e o cliente tem dire...  Política 2.3
# 4  Reembolso automático, salvo exceções operacion...  Política 2.3

# %%
df.shape
# Out:
# (20, 4)

# %% [markdown]
# # Lendo respostas geradas pelo agente

# %%
results = pd.read_csv("results/respostas_agente_ifood.csv")

for index, row in results.iterrows():
    print(f"Pergunta: {row['pergunta']}")
    print(f"Resposta: {row['resposta']}\n")
# Out:
# Pergunta: O cliente quer reembolso, mas o pedido já saiu para entrega. O reembolso ainda é permitido?
# Resposta: O reembolso ainda pode ser permitido, mas apenas se houver falha do restaurante, do app ou do entregador. Se a solicitação de reembolso for devido à desistência do cliente após o pedido ter saído para entrega, pode não ser elegível. Portanto, é importante verificar as circunstâncias específicas do caso.
#
# Pergunta: O restaurante cancelou por falta de ingrediente. O reembolso é automático?
# Resposta: Sim, o reembolso é automático quando o restaurante cancela o pedido por falta de ingrediente.
#
# Pergunta: O cliente foi cobrado após o cancelamento. O que fazer?
# Resposta: É necessário validar o status do estorno. Em alguns métodos de pagamento, a devolução pode levar até 14 dias. Se o cliente foi cobrado após o cancelamento, verifique se o pedido foi cancelado corretamente e se o estorno está em processo.
